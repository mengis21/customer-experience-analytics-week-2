# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('../data/clean_reviews.csv')
df.head()
# Out:
#           review  rating        date bank       source
# 0      thank you       5  2025-12-01  CBE  google_play
# 1  very good app       5  2025-12-01  CBE  google_play
# 2      excellent       1  2025-12-01  CBE  google_play
# 3           good       5  2025-11-30  CBE  google_play
# 4      CBE ይለያል።       5  2025-11-29  CBE  google_play

# %%
df.shape
# Out:
# (1523, 5)

# %%
df['bank'].value_counts()
# Out:
# bank
# BOA       524
# Dashen    524
# CBE       475
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='rating')
plt.title('Rating Distribution')
plt.show()

# %%
# Sentiment distribution
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
en = pd.read_csv('../data/clean_reviews_enriched.csv')
sns.countplot(data=en, x='sentiment_label', order=['negative','neutral','positive'])
plt.title('Sentiment Label Distribution')
plt.show()

# %%
# Top keywords per bank
import pandas as pd
en = pd.read_csv('../data/clean_reviews_enriched.csv')
en.groupby('bank')['keywords'].first()
